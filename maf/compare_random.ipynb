# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
rng = np.random.default_rng(seed=42)

# %%
s1 = rng.normal(0, size=1000)*11**.5 + 11
s2 = rng.normal(0, size=1000)*9**.5 + 9

# %%
np.where(s2 > s1)[0].size
# Out:
# 340

# %%
plt.plot(s1, 'ko')
