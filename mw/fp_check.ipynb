# %%
from lmc_filter_balance import CustomAreaMap
import healpy as hp
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np

# %%
nside = 32
sky = CustomAreaMap(nside=nside, smc_radius=4, lmc_radius=6)
footprints_hp_array, labels = sky.return_maps()

# %%
hp.mollview(footprints_hp_array['g'])

# %%
dir(CustomAreaMap)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_set_bulge_diamond',
#  '_set_bulge_rectangle',
#  '_set_circular_region',
#  'add_bulge',
#  'add_bulgy',
#  'add_dusty_plane',
#  'add_euclid_overlap',
#  'add_lowdust_wfd',
#  'add_magellanic_clouds',
#  'add_nes',
#  'add_scp',
#  'add_virgo_cluster',
#  'estimate_visits',
#  'estimate_visits_per_label',
#  'read_dustmap',
#  'return_maps']

# %%
ack, sm, lables = sky.estimate_visits(2.1e6)

# %%
hp.mollview(ack['r'])

# %%
indx = np.where(labels == 'scp')[0]
np.unique(ack['r'][indx]), np.unique(ack['g'][indx]), np.unique(ack['y'][indx])
# Out:
# (array([27.68418908]), array([27.68418908]), array([9.63819916]))

# %%
.135/27*35
# Out:
# 0.17500000000000002
